# %%
cd EMD_BiLSTM
# Out:
# d:\iTek-workshop\EMD_BiLSTM

# %%
# !python EMD_decompose.py
# Out:
# Figure(600x1950)

# %%
# !python Train.py   ##for imf 0
# Out:
# Number train samples: 6912
# Number validation samples: 1080
# Number test samples: 1075
# Epoch 1/500
#
# ...
# 108/108 [==============================] - 5s 16ms/step - loss: 0.0546 - val_loss: 0.0023
# Epoch 2/500
#
# ...
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0104 - val_loss: 0.0020
# Epoch 3/500
#
# ...
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0086 - val_loss: 0.0020
# Epoch 4/500
#
# ...
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0079 - val_loss: 0.0021
# Epoch 5/500
#
# ...
#  98/108 [==========================>...] - ETA: 0s - loss: 0.0071
# Epoch 5: val_loss improved from inf to 0.00201, saving model to ./result/hourly/trained/imf_0\weights.05-0.00.h5
#
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 6/500
#
# ...
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0018
# Epoch 7/500
#
# ...

# %%
# !python Train.py   ###for imf 1
# Out:
# Number train samples: 6912
# Number validation samples: 1080
# Number test samples: 1071
# Epoch 1/500
#
# ...
# 108/108 [==============================] - 5s 20ms/step - loss: 0.0586 - val_loss: 0.0015
# Epoch 2/500
#
# ...
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0163 - val_loss: 0.0017
# Epoch 3/500
#
# ...
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0142 - val_loss: 0.0014
# Epoch 4/500
#
# ...
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0126 - val_loss: 0.0020
# Epoch 5/500
#
# ...
# 108/108 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 5: val_loss improved from inf to 0.00137, saving model to ./result/hourly/trained/imf_1\weights.05-0.00.h5
#
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0114 - val_loss: 0.0014
# Epoch 6/500
#
# ...
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0108 - val_loss: 0.0021
# Epoch 7/500
#
# ...
